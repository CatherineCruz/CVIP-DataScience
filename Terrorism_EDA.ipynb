# %% [markdown]
# # Exploratory Data Analysis of Global Terrorism
#
# ## <font color='blue'> Project Overview:
#
# The Exploratory Data Analysis (EDA) of Global Terrorism Incidents project aims to analyze and gain insights from a comprehensive dataset on global terrorism incidents. The dataset provides information on various aspects of terrorism, including geographical locations, types of attacks, targets, and casualties. The primary goal is to explore patterns, trends, and factors associated with terrorism worldwide.

# %% [markdown]
# ## <font color='blue'>Objectives:
#
# **<font color='brown'>Data Exploration:</font>**
# 1. Gain a deep understanding of the dataset's structure and contents.
# 2. Identify key variables and their distributions.
# 3. Explore missing values, outliers, and data quality issues.
#
# **<font color='brown'>Geospatial Analysis:</font>**
# 1. Visualize the geographical distribution of terrorism incidents on a world map.
# 2. Analyze hotspots and trends in different regions over time.
# 3. Investigate relationships between terrorism and geopolitical factors.
#
# **<font color='brown'>Target Analysis:</font>**
# 1. Analyze the types of targets chosen by terrorists.
# 2. Explore changes in targeting preferences over time.
# 3. Identify high-profile targets or sectors frequently impacted.
#
# **<font color='brown'>Casualty Analysis:</font>**
# 1. Investigate the number of casualties associated with different types of attacks.
# 2. Analyze trends in casualties over time and across regions.
# 3. Identify factors contributing to variations in casualty counts.
#
# **<font color='brown'>Group and Perpetrator Analysis:</font>**
# 1. Examine the involvement of different terrorist groups.
# 2. Identify patterns in the tactics and strategies employed by various groups.
# 3. Explore the influence of specific groups on global terrorism trends.

# %% [markdown]
# ## <font color='blue'>Tools and Technologies:</font>
#
# 1. **<font color='brown'>Programming Language:</font>** Python
#
# 2. **<font color='brown'>Libraries:</font>**
#    - Pandas
#    - NumPy
#    - Matplotlib
#    - Seaborn
#    - Geopandas
#
# 3. **<font color='brown'>Data Visualization:</font>**
#    - Matplotlib
#    - Seaborn
#
# 4. **<font color='brown'>Statistical Analysis:</font>** Descriptive statistics
#
# 5. **<font color='brown'>Geospatial Analysis:</font>** Mapping using Geopandas

# %% [markdown]
# ![Alt text](https://t3.ftcdn.net/jpg/01/13/51/10/360_F_113511057_Vj1r54udSVJi5IVMElQ7VXNwyF6pTzMp.jpg)

# %%
#import the required library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\cathe\\Downloads\\Terrorism\\Terrorism_EDA.csv", encoding='latin1', low_memory=False)
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#number of rows and columns in the dataset
df.shape
# Out:
# (181691, 135)

# %%
#names of all columns
for n in df.columns:
    print(n)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %%
#data types of all the columns
df.dtypes
# Out:
# eventid       float64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG         int64
# INT_IDEO        int64
# INT_MISC        int64
# INT_ANY         int64
# related        object
# Length: 135, dtype: object

# %%
#changing the data type of column eventid to integers
df['eventid'] = df['eventid'].fillna(0)
df['eventid'] = df['eventid'].astype(int)

# %%
# general description of columns
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean  -2.147484e+09    2002.638997       6.467277      15.505644
# std    0.000000e+00      13.259430       3.388303       8.814045
# min   -2.147484e+09    1970.000000       0.000000       0.000000
# 25%   -2.147484e+09    1991.000000       4.000000       8.000000
# 50%   -2.147484e+09    2009.000000       6.000000      15.000000
# 75%   -2.147484e+09    2014.000000       9.000000      23.000000
# max   -2.147484e+09    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# DATA CLEANING

# %%
#EXTRACT ONLY REQUIRED COLUMNS FROM ORIGINAL DATASET
df= df[['iyear','country_txt','region_txt','city','attacktype1_txt','targtype1_txt','gname','nkill']]
df.head()
# Out:
#    iyear         country_txt                   region_txt           city  \
# 0   1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1   1970              Mexico                North America    Mexico city
# 2   1970         Philippines               Southeast Asia        Unknown
# 3   1970              Greece               Western Europe         Athens
# 4   1970               Japan                    East Asia        Fukouka
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                 gname  nkill
# 0                              MANO-D    1.0
# 1  23rd of September Communist League    0.0
# ...

# %%
#sum of all null values in the columns
df.isnull().sum()
# Out:
# iyear                  0
# country_txt            0
# region_txt             0
# city                 434
# attacktype1_txt        0
# targtype1_txt          0
# gname                  0
# nkill              10313
# dtype: int64

# %%
#drop all rows which have null values
df = df.dropna()

# %%
df.rename(columns ={'iyear':'year','country_txt':'country','region_txt':'region','attacktype1_txt':'attacktype','targtype1_txt':'target','gname':'organization','nkill':'killed'}, inplace = True)

# %%
df.head()
# Out:
#    year             country                       region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 5  1970       United States                North America          Cairo
# 6  1970             Uruguay                South America     Montevideo
#
#                     attacktype                       target  \
# 0                Assassination  Private Citizens & Property
# 1  Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                Assassination          Journalists & Media
# 5                Armed Assault                       Police
# 6                Assassination                       Police
#
#                          organization  killed
# 0                              MANO-D     1.0
# 1  23rd of September Communist League     0.0
# ...

# %%
df.isnull().sum()
# Out:
# year                0
# country             0
# region              0
# city              434
# attacktype          0
# target              0
# organization        0
# killed          10313
# dtype: int64

# %%
df.dtypes
# Out:
# year              int64
# country          object
# region           object
# city             object
# attacktype       object
# target           object
# organization     object
# killed          float64
# dtype: object

# %%
#sort the dataset in descending order of the killed column
df.sort_values(by=['killed'],ascending =False).head(10)
# Out:
#         year        country                      region              city  \
# 133518  2014           Iraq  Middle East & North Africa            Tikrit
# 73126   2001  United States               North America     New York City
# 73127   2001  United States               North America     New York City
# 55934   1994         Rwanda          Sub-Saharan Africa            Gikoro
# 136283  2014           Iraq  Middle East & North Africa            Sinjar
# 133225  2014           Iraq  Middle East & North Africa            Badush
# 179671  2017        Somalia          Sub-Saharan Africa         Mogadishu
# 76347   2004          Nepal                  South Asia  Dhading district
# 136746  2014          Syria  Middle East & North Africa           Unknown
# 170198  2016          Syria  Middle East & North Africa           Palmyra
#
#                          attacktype                       target  \
# 133518  Hostage Taking (Kidnapping)                     Military
# ...

# %%
#drop row number 73216
df = df.drop([73216])

# %%
#sort the dataset in descending order of the killed column
df.sort_values(by=['killed'],ascending =False).head(10)
# Out:
#         year        country                      region              city  \
# 133518  2014           Iraq  Middle East & North Africa            Tikrit
# 73126   2001  United States               North America     New York City
# 73127   2001  United States               North America     New York City
# 55934   1994         Rwanda          Sub-Saharan Africa            Gikoro
# 136283  2014           Iraq  Middle East & North Africa            Sinjar
# 133225  2014           Iraq  Middle East & North Africa            Badush
# 179671  2017        Somalia          Sub-Saharan Africa         Mogadishu
# 76347   2004          Nepal                  South Asia  Dhading district
# 136746  2014          Syria  Middle East & North Africa           Unknown
# 170198  2016          Syria  Middle East & North Africa           Palmyra
#
#                          attacktype                       target  \
# 133518  Hostage Taking (Kidnapping)                     Military
# ...

# %%
#change datatype of killed column from float to int
df=df.astype({'killed':'int'})

# %%
df.dtypes
# Out:
# year             int64
# country         object
# region          object
# city            object
# attacktype      object
# target          object
# organization    object
# killed           int32
# dtype: object

# %%
df.head()
# Out:
#    year             country                       region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 5  1970       United States                North America          Cairo
# 6  1970             Uruguay                South America     Montevideo
#
#                     attacktype                       target  \
# 0                Assassination  Private Citizens & Property
# 1  Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                Assassination          Journalists & Media
# 5                Armed Assault                       Police
# 6                Assassination                       Police
#
#                          organization  killed
# 0                              MANO-D       1
# 1  23rd of September Communist League       0
# ...

# %%
#number of rows and columns in the dataset
df.shape
# Out:
# (170943, 8)

# %%
# general description of columns
df.describe()
# Out:
#                 year         killed
# count  170943.000000  170943.000000
# mean     2003.066537       2.406024
# std        12.956648      11.559841
# min      1970.000000       0.000000
# 25%      1991.000000       0.000000
# 50%      2009.000000       0.000000
# 75%      2014.000000       2.000000
# max      2017.000000    1570.000000

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Number of terrorist attacks over years</u></font></h2>
# </div>

# %%
# Annual terrorist attack statistics
plt.subplots(figsize=(25,8))
sns.countplot(x='year', data=df, palette='plasma', ec='black')
plt.xticks(rotation=90)
plt.xlabel("Year",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above graph , we can infer that the maximum number attacks took place in the year "2014"

# %%
#Creating a dataset region type
r_type =df.region.value_counts().to_frame().reset_index()
r_type

#changing the name
r_type.columns=['region_name','count']
r_type

#Terrorist attacks in each region

sns.barplot(y='region_name', x='count',orient='h', data=r_type,palette='crest', edgecolor='black')
plt.xlabel('Count', fontsize=14)
plt.ylabel('Region', fontsize=14)
plt.title('Terrorist activities by region - Countplot', fontsize=16)
plt.show()

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Terrorist activities by region in each year</u></font></h2>
# </div>

# %%
#extract year column of the dataset
df.year
# Out:
# 0         1970
# 1         1970
# 2         1970
# 5         1970
# 6         1970
#           ...
# 181686    2017
# 181687    2017
# 181688    2017
# 181689    2017
# 181690    2017
# Name: year, Length: 170943, dtype: int64

# %%
#extract region column of the dataset 
df.region
# Out:
# 0         Central America & Caribbean
# 1                       North America
# 2                      Southeast Asia
# 5                       North America
# 6                       South America
#                      ...
# 181686             Sub-Saharan Africa
# 181687     Middle East & North Africa
# 181688                 Southeast Asia
# 181689                     South Asia
# 181690                 Southeast Asia
# Name: region, Length: 170943, dtype: object

# %%
#Terrorist attack - region wise and year wise 
heatmap_data = pd.crosstab(df.year, df.region)
plt.figure(figsize=(20, 6))
sns.heatmap(heatmap_data, cmap='Reds')

plt.xlabel("Region", fontsize=20)
plt.ylabel("Year", fontsize=20)
plt.title("Terrorist activities by region each year", fontsize=20)
plt.show()

# %%
#Terrorist attack - region wise and year wise 
pd.crosstab(df.year, df.region).plot(kind='line', marker='o', figsize=(10, 6))

plt.title('Terrorist activities by region each year')
plt.xlabel("Year",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.grid(False)
plt.show()

# %% [markdown]
# From the above two visualizations , we can see that after the year "2010", terrorist attacks had been increased all over the world , especially in regions like Middle east and north Africa,South Asia and Sub-Saharan Africa

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Total number of attacks on each country
# </u></font></h2>
# </div>

# %%
#create a dataset top10_country
top10_country=df.country.value_counts()[:10].to_frame().reset_index()
top10_country
# Out:
#             index  country
# 0            Iraq    23895
# 1        Pakistan    14108
# 2     Afghanistan    12223
# 3           India    11740
# 4        Colombia     7848
# 5     Philippines     6693
# 6            Peru     5457
# 7  United Kingdom     5065
# 8          Turkey     4160
# 9     El Salvador     3939

# %%
top10_country.columns=['country_name','count']
top10_country
# Out:
#      country_name  count
# 0            Iraq  23895
# 1        Pakistan  14108
# 2     Afghanistan  12223
# 3           India  11740
# 4        Colombia   7848
# 5     Philippines   6693
# 6            Peru   5457
# 7  United Kingdom   5065
# 8          Turkey   4160
# 9     El Salvador   3939

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# Load world map with country boundaries
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))



# Merge with world map based on country name
merged_data = world.merge(top10_country, how='left', left_on='name', right_on='country_name')

# Plot the map
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Plot all countries with a light gray outline
world.plot(ax=ax, color='lightgray', edgecolor='0.8')

# Highlight the top countries
merged_data.plot(column='count', cmap='plasma', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

ax.set_title('Countries with most attacks')
plt.show()

# %%
#Plot for countries most affected  by terrorism
plt.figure(figsize =(15,5))
sns.barplot(y='country_name', x='count', orient='h', data=top10_country, palette='muted', edgecolor='black')
plt.title('10 Countries with most terrorist attacks')
plt.xlabel("Year",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.grid(False)
plt.show()

# %% [markdown]
# <font color='red'>From the above plot, we can infer that <font color='blue'>'IRAN' <font color='red'>is the most affected country from terrorism

# %% [markdown]
#  <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Target Methods by terrorist</u></font></h2>
# </div>

# %%
#create a dataframe a_type
a_type = df.attacktype.value_counts()[:10].to_frame().reset_index()
a_type
# Out:
#                                  index  attacktype
# 0                    Bombing/Explosion       88255
# 1                        Armed Assault       42669
# 2                        Assassination       19312
# 3          Hostage Taking (Kidnapping)       11158
# 4       Facility/Infrastructure Attack       10356
# 5                              Unknown        7276
# 6                      Unarmed Assault        1015
# 7  Hostage Taking (Barricade Incident)         991
# 8                            Hijacking         659

# %%
#change the column name of the a_type dataset
a_type.columns=['attack_type','count']
a_type
# Out:
#                            attack_type  count
# 0                    Bombing/Explosion  88255
# 1                        Armed Assault  42669
# 2                        Assassination  19312
# 3          Hostage Taking (Kidnapping)  11158
# 4       Facility/Infrastructure Attack  10356
# 5                              Unknown   7276
# 6                      Unarmed Assault   1015
# 7  Hostage Taking (Barricade Incident)    991
# 8                            Hijacking    659

# %%
#bar plot to show which method is most used attack type
plt.figure(figsize=(35,10))
sns.barplot(x='attack_type',y='count',data=a_type,palette ='coolwarm',ec='black')
plt.title('Attack type of Terrrorists',fontsize=30)
plt.xlabel("Attack type",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# <font color='red'> From the above plot ,we could observe that <font color='blue'>"Bombing/Explosion" <font color='red'>is the most common attack type of terrorists

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>The terrorist groups with the highest level of activity </u></font></h2>
# </div>

# %%
#create a dataset g_type
g_type =df.organization.value_counts()[:5].to_frame().reset_index()
g_type
# Out:
#                                               index  organization
# 0                                           Unknown         82782
# 1                                           Taliban          7478
# 2       Islamic State of Iraq and the Levant (ISIL)          5613
# 3                                 Shining Path (SL)          4555
# 4  Farabundo Marti National Liberation Front (FMLN)          3351

# %%
#change the column name of the g_type dataset
g_type.columns=['organizations','count']
g_type
# Out:
#                                       organizations  count
# 0                                           Unknown  82782
# 1                                           Taliban   7478
# 2       Islamic State of Iraq and the Levant (ISIL)   5613
# 3                                 Shining Path (SL)   4555
# 4  Farabundo Marti National Liberation Front (FMLN)   3351

# %%
#bar plot to show which terrorist groups are most active
plt.figure(figsize=(35,10))
sns.barplot(x='organizations',y='count',data=g_type,palette ='bright',ec='black')
plt.title('Most active Terrrorists organizations',fontsize=30)
plt.xlabel("Organization",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# <font color='red'> From the above plot ,we could observe that <font color='blue'>"TALIBAN" <font color='red'>is the most active terrorists organization

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Number of Total Casualities in each country </u></font></h2>
# </div>

# %%
casualities=df.groupby('country').killed.sum().to_frame().reset_index().sort_values('killed',ascending=False)[0:10]
casualities
# Out:
#          country   killed
# 84          Iraq  78589.0
# 0    Afghanistan  39384.0
# 134     Pakistan  23822.0
# 130      Nigeria  22682.0
# 80         India  19341.0
# 167    Sri Lanka  15530.0
# 175        Syria  15229.0
# 35      Colombia  14698.0
# 139         Peru  12771.0
# 52   El Salvador  12053.0

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='country',y='killed',data=casualities,ec='black')
plt.title('Countries with severe attacks',fontsize=30)
plt.xlabel("Country Name",fontsize=20)
plt.ylabel("No of people killed",fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# <font color='red'> From the above plot ,we could observe that <font color='blue'>"IRAN" <font color='red'>is the most suffered country with the maximum no of killings because of terrorism

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'> Cities with maximum attacks all over the world </u></font></h2>
# </div>

# %%
#create a dataset cities
df = df[df['city'] != 'Unknown']

cities =df.city.value_counts()[:10].to_frame().reset_index()
cities
# Out:
#           index  city
# 0       Baghdad  7589
# 1       Karachi  2652
# 2          Lima  2359
# 3         Mosul  2265
# 4       Belfast  2171
# 5      Santiago  1621
# 6     Mogadishu  1581
# 7  San Salvador  1558
# 8      Istanbul  1048
# 9        Athens  1019

# %%
cities.columns=['city','count']
cities
# Out:
#            city  count
# 0       Baghdad   7589
# 1       Karachi   2652
# 2          Lima   2359
# 3         Mosul   2265
# 4       Belfast   2171
# 5      Santiago   1621
# 6     Mogadishu   1581
# 7  San Salvador   1558
# 8      Istanbul   1048
# 9        Athens   1019

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='city',y='count',data=cities,palette = 'Set3',ec='black')
plt.title('Cities with severe attacks',fontsize=30)
plt.xlabel("Cities Name",fontsize=20)
plt.ylabel("No of times being attacked",fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# <font color='red'> From the above plot ,we could observe that <font color='blue'>"BAGHDAD" <font color='red'>is the most suffered city with the maximum no of terrorist attacks

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Time Line of number of people killed in the region "AMERICA" which includes <u>'North America', 'South America', 'Central America & Caribbean'</u></font></h2>
# </div>

# %%
# Creating a dataset region1
region1 = df[(df['region'] == 'North America') | (df['region'] == 'South America') | (df['region'] == 'Central America & Caribbean')]

region1
# Out:
#         year             country                       region  \
# 0       1970  Dominican Republic  Central America & Caribbean
# 1       1970              Mexico                North America
# 5       1970       United States                North America
# 6       1970             Uruguay                South America
# 7       1970       United States                North America
# ...      ...                 ...                          ...
# 181415  2017              Mexico                North America
# 181444  2017            Colombia                South America
# 181478  2017       United States                North America
# 181479  2017       United States                North America
# 181516  2017            Colombia                South America
#
#                    city                   attacktype  \
# 0         Santo Domingo                Assassination
# 1           Mexico city  Hostage Taking (Kidnapping)
# 5                 Cairo                Armed Assault
# ...

# %%
# Creating a dataset region1_c

region1_c = region1.groupby(['country', 'year'])['killed'].size().reset_index()
region1_c
# Out:
#                  country  year  killed
# 0    Antigua and Barbuda  1992       1
# 1              Argentina  1970      20
# 2              Argentina  1971       7
# 3              Argentina  1972      20
# 4              Argentina  1973      58
# ..                   ...   ...     ...
# 754            Venezuela  2013       1
# 755            Venezuela  2014       4
# 756            Venezuela  2015       3
# 757            Venezuela  2016       6
# 758            Venezuela  2017      17
#
# [759 rows x 3 columns]

# %%
plt.figure(figsize=(25,10))
sns.lineplot(x='year',y='killed',hue='country',data=region1_c,palette = 'magma_r')
plt.title("Total People killed in the 'AMERICA' region over years",fontsize=30)
plt.xlabel("Year",fontsize=20)
plt.ylabel("No of people killed",fontsize=20)
plt.grid(True)
plt.show()

# %%
top_10_countries = region1_c.groupby('country')['killed'].sum().nlargest(10).index
top_10_df = region1_c[region1_c['country'].isin(top_10_countries)]

# Now you can use top_10_df for plotting
plt.figure(figsize=(10, 6))
for country, data in top_10_df.groupby('country'):
    plt.plot(data['year'], data['killed'], label=country)

plt.title('Top 10 Countries in the region America with maximum number of killings over years')
plt.xlabel('Year')
plt.ylabel('Number of Killed Incidents')
plt.legend()
plt.show()

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Time Line of number of people killed in the region "ASIA" which includes <u>'South Asia', 'Southeast Asia', 'Central Asia'</u></font></h2>
# </div>

# %%
region2 = df[(df['region'] == 'South Asia' ) | (df['region'] == 'Southeast Asia' ) | (df['region'] == 'East Asia' )| (df['region'] == 'Central Asia' )]
region2
# Out:
#         year      country          region           city  \
# 4       1970        Japan       East Asia        Fukouka
# 26      1970  Philippines  Southeast Asia    Quezon City
# 39      1970  Philippines  Southeast Asia         Bamban
# 96      1970  Philippines  Southeast Asia         Manila
# 150     1970  Philippines  Southeast Asia        Angeles
# ...      ...          ...             ...            ...
# 181684  2017        India      South Asia        Hungrum
# 181685  2017  Afghanistan      South Asia        Maymana
# 181688  2017  Philippines  Southeast Asia       Kubentog
# 181689  2017        India      South Asia         Imphal
# 181690  2017  Philippines  Southeast Asia  Cotabato City
#
#                             attacktype                       target  \
# 4       Facility/Infrastructure Attack      Government (Diplomatic)
# 26                   Bombing/Explosion      Government (Diplomatic)
# 39                             Unknown                     Military
# ...

# %%
# Creating a dataset region2_c

region2_c = region2.groupby(['country', 'year'])['killed'].size().reset_index()
region2_c
top_10_countries2 = region2_c.groupby('country')['killed'].sum().nlargest(10).index
top_10_df2 = region2_c[region2_c['country'].isin(top_10_countries2)]

# Now you can use top_10_df for plotting
plt.figure(figsize=(10, 6))
for country, data in top_10_df2.groupby('country'):
    plt.plot(data['year'], data['killed'], label=country)

plt.title('Top 10 Countries in the region Asia with maximum number of killings over years')
plt.xlabel('Year')
plt.ylabel('Number of Killed Incidents')
plt.legend()
plt.show()

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>The Year in which most Iraqis died of terrorist attacks and the organization responsible<u></u></font></h2>
# </div>

# %%
df = df[df['organization'] != 'Unknown']
df.head()
# Out:
#    year             country                       region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 5  1970       United States                North America          Cairo
# 6  1970             Uruguay                South America     Montevideo
# 8  1970       United States                North America        Madison
#
#                        attacktype                       target  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 5                   Armed Assault                       Police
# 6                   Assassination                       Police
# 8  Facility/Infrastructure Attack                     Military
#
#                          organization  killed
# 0                              MANO-D     1.0
# 1  23rd of September Communist League     0.0
# ...

# %%
#create a dataset iraq_deadyears
iraq_deadyears=df[df ['country'] == 'Iraq'].sort_values(by =['killed'],ascending=False)
iraq_deadyears.head()
# Out:
#         year country                      region     city  \
# 133518  2014    Iraq  Middle East & North Africa   Tikrit
# 136283  2014    Iraq  Middle East & North Africa   Sinjar
# 133225  2014    Iraq  Middle East & North Africa   Badush
# 136561  2014    Iraq  Middle East & North Africa     Kojo
# 164327  2016    Iraq  Middle East & North Africa  Baghdad
#
#                          attacktype                       target  \
# 133518  Hostage Taking (Kidnapping)                     Military
# 136283  Hostage Taking (Kidnapping)  Private Citizens & Property
# 133225                Armed Assault                       Police
# 136561  Hostage Taking (Kidnapping)  Private Citizens & Property
# 164327            Bombing/Explosion                     Business
#
#                                        organization  killed
# 133518  Islamic State of Iraq and the Levant (ISIL)  1570.0
# 136283  Islamic State of Iraq and the Levant (ISIL)   953.0
# ...

# %%
iraq_deadyears.year.value_counts()
# Out:
# 2014    3849
# 2016    3293
# 2013    2711
# 2015    2697
# 2017    2399
# 2012    1390
# 2011    1302
# 2010    1179
# 2009    1136
# 2008    1100
# 2007    1030
# 2006     823
# 2005     598
# 2004     306
# 2003      99
# 1992      32
# 1997      20
# 1994      17
# 1995      12
# 1996      12
# 1999      10
# 2000       9
# 1998       7
# 1980       6
# 2002       5
# 1988       4
# 1982       4
# 2001       3
# 1976       3
# 1991       3
# 1983       3
# 1989       3
# 1987       3
# 1979       2
# 1981       2
# 1984       1
# 1975       1
# Name: year, dtype: int64

# %%
iraq_deadyears=iraq_deadyears[iraq_deadyears['year']== 2014]
iraq_deadyears
# Out:
#         year country                      region              city  \
# 133518  2014    Iraq  Middle East & North Africa            Tikrit
# 136283  2014    Iraq  Middle East & North Africa            Sinjar
# 133225  2014    Iraq  Middle East & North Africa            Badush
# 136561  2014    Iraq  Middle East & North Africa              Kojo
# 141638  2014    Iraq  Middle East & North Africa          Fallujah
# ...      ...     ...                         ...               ...
# 141142  2014    Iraq  Middle East & North Africa           Shirqat
# 141255  2014    Iraq  Middle East & North Africa           Baldagh
# 141280  2014    Iraq  Middle East & North Africa          Sudayrah
# 141521  2014    Iraq  Middle East & North Africa  Hawijah district
# 141629  2014    Iraq  Middle East & North Africa             Baiji
#
#                          attacktype                       target  \
# 133518  Hostage Taking (Kidnapping)                     Military
# ...

# %%
iraq_deadyears.killed.sum()
# Out:
# 8854.0

# %%
irad_org=iraq_deadyears['organization'].value_counts()[:5].to_frame().reset_index()
irad_org
# Out:
#                                                index  organization
# 0        Islamic State of Iraq and the Levant (ISIL)          1075
# 1                              Al-Naqshabandiya Army            22
# 2  Military Council of the Tribal Revolutionaries...            20
# 3                                  Muslim extremists            18
# 4                                 Asa'ib Ahl al-Haqq             2

# %%
irad_org.columns=['Organization','Attacks']
irad_org
# Out:
#                                         Organization  Attacks
# 0        Islamic State of Iraq and the Levant (ISIL)     1075
# 1                              Al-Naqshabandiya Army       22
# 2  Military Council of the Tribal Revolutionaries...       20
# 3                                  Muslim extremists       18
# 4                                 Asa'ib Ahl al-Haqq        2

# %%
plt.figure(figsize=(35,10))
sns.barplot(x='Organization',y='Attacks',data=irad_org,palette = 'Set3',ec='black')
plt.title('Attacks of Organization ',fontsize=30)
plt.xlabel("Organizations Name",fontsize=20)
plt.ylabel("No of attacks",fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# <font color='red'> From the above plot ,we could observe that <font color='blue'>"2014" <font color='red'>is the year in which Iraqis suffered the most deaths because of terrorist attacks and the organization which could be held responsible for maximum number of attacks on Iraqis is <font color='blue'> "Islamic State of Iraq and the Levant (ISIL)".

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Targets of Terrorists<u></u></font></h2>
# </div>

# %%
a = list(df['target'].value_counts().head())
b = list(df['target'].value_counts().head().keys())
pastel_palette = sns.color_palette("pastel")
plt.figure(figsize=(25, 10))
plt.bar(b, a, color=pastel_palette, edgecolor='black')
plt.title('Targets of terrorists', fontsize=30)
plt.xlabel("Targets Name", fontsize=20)
plt.ylabel("No of attacks", fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# <font color='red'> From the above plot ,we could observe that <font color='blue'>"private citizens & property" <font color='red'>is the most attacked target in terrorist attacks

# %% [markdown]
# <div style="background-color: #E6DCEC; padding: 10px;">
#     <h2><font color='black'>Deadliest Year in terms of death by Terrorism<u></u></font></h2>
# </div>

# %%
years=(df.groupby(['year'])['killed'].size().reset_index())
years
# Out:
#     year  killed
# 0   1970     529
# 1   1971     367
# 2   1972     476
# 3   1973     352
# 4   1974     457
# 5   1975     599
# 6   1976     595
# 7   1977     777
# 8   1978     971
# 9   1979    1693
# 10  1980    1379
# 11  1981    1279
# 12  1982    1439
# 13  1983    2053
# 14  1984    2235
# 15  1985    1952
# 16  1986    1934
# 17  1987    2341
# 18  1988    2593
# 19  1989    2986
# 20  1990    2476
# 21  1991    3002
# 22  1992    3014
# 23  1994    1805
# 24  1995    1312
# 25  1996    1173
# 26  1997    1041
# 27  1998     430
# 28  1999     693
# 29  2000    1049
# 30  2001    1066
# 31  2002     812
# 32  2003     752
# 33  2004     528
# 34  2005     880
# 35  2006     928
# 36  2007     979
# 37  2008    1752
# 38  2009    1773
# 39  2010    1882
# 40  2011    1811
# 41  2012    3440
# 42  2013    3846
# 43  2014    7708
# 44  2015    8143
# 45  2016    7249
# 46  2017    6317

# %%
years_dead=years.sort_values(by=['killed'],ascending = False).head()
years_dead
# Out:
#     year  killed
# 44  2015    8143
# 43  2014    7708
# 45  2016    7249
# 46  2017    6317
# 42  2013    3846

# %%
c = list(years_dead['year'])
d = list(years_dead['killed'])
pastel_palette = sns.color_palette("Set2")
plt.figure(figsize=(25, 10))
plt.bar(c, d, color=pastel_palette, edgecolor='black')
plt.title('No of People killed over years', fontsize=30)
plt.xlabel("Year", fontsize=20)
plt.ylabel("No of people killed", fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# <font color='red'> From the above plot ,we could observe that <font color='blue'>"2015" <font color='red'>is the year in which  people all over world suffered most deaths because of terrorist attacks

# %% [markdown]
# ## <font color='blue'> Conclusion

# %% [markdown]
# The EDA of Global Terrorism Incidents project aims to provide valuable insights into the patterns and trends of terrorism incidents worldwide. The analysis will contribute to a better understanding of the factors associated with terrorism, aiding in the development of informed strategies for prevention and response.
